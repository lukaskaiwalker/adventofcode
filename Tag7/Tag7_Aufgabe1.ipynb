# %%
file = open('Aufgabe7.csv', 'r')
Lines = file.readlines()
Lines
# Out:
# ['clear maroon bags contain 1 dull lavender bag.\n', 'wavy turquoise bags contain 4 vibrant magenta bags, 4 light violet bags, 5 bright gold bags, 2 faded black bags.\n', 'wavy beige bags contain 3 plaid magenta bags, 3 wavy lime bags, 2 clear turquoise bags, 3 muted cyan bags.\n', 'mirrored black bags contain 1 plaid red bag, 3 light gold bags, 3 wavy violet bags.\n', 'vibrant fuchsia bags contain 2 dark lime bags, 2 mirrored black bags, 2 light magenta bags, 2 drab chartreuse bags.\n', 'vibrant plum bags contain 4 dim cyan bags, 3 pale maroon bags.\n', 'dark tan bags contain 3 faded white bags, 3 wavy tan bags, 4 pale indigo bags.\n', 'faded green bags contain 2 dim cyan bags, 5 dim magenta bags, 2 wavy maroon bags, 2 faded white bags.\n', 'clear black bags contain 4 striped green bags, 2 dim violet bags, 1 dull tan bag.\n', 'light olive bags contain 5 striped indigo bags, 3 dim coral bags, 1 drab bronze bag, 3 mirrored beige bags.\n', 'dim black bags contain 1 faded tan bag, 5 shi
# ...

# %%
def inhaltSucher(rest_string, start):
    rest_string.index(',')

# %%
Inhalt=[]
appender=[]
for line in Lines:
    starter=line.index(" bags contain")
    
    container = line[:starter]
    first_bag = line[starter+14:]
    
    appender= container, first_bag.split(', ')
    Inhalt.append(appender)
print(Inhalt)
# Out:
# [('clear maroon', ['1 dull lavender bag.\n']), ('wavy turquoise', ['4 vibrant magenta bags', '4 light violet bags', '5 bright gold bags', '2 faded black bags.\n']), ('wavy beige', ['3 plaid magenta bags', '3 wavy lime bags', '2 clear turquoise bags', '3 muted cyan bags.\n']), ('mirrored black', ['1 plaid red bag', '3 light gold bags', '3 wavy violet bags.\n']), ('vibrant fuchsia', ['2 dark lime bags', '2 mirrored black bags', '2 light magenta bags', '2 drab chartreuse bags.\n']), ('vibrant plum', ['4 dim cyan bags', '3 pale maroon bags.\n']), ('dark tan', ['3 faded white bags', '3 wavy tan bags', '4 pale indigo bags.\n']), ('faded green', ['2 dim cyan bags', '5 dim magenta bags', '2 wavy maroon bags', '2 faded white bags.\n']), ('clear black', ['4 striped green bags', '2 dim violet bags', '1 dull tan bag.\n']), ('light olive', ['5 striped indigo bags', '3 dim coral bags', '1 drab bronze bag', '3 mirrored beige bags.\n']), ('dim black', ['1 faded tan bag', '5 shiny crimson bags.\n']),
# ...

# %%
appender=[]

for line in Lines:
    line = line.replace(' bags contain ', ', ')
    line = line.split(', ')
print(Lines)
# Out:
# ['clear maroon bags contain 1 dull lavender bag.\n', 'wavy turquoise bags contain 4 vibrant magenta bags, 4 light violet bags, 5 bright gold bags, 2 faded black bags.\n', 'wavy beige bags contain 3 plaid magenta bags, 3 wavy lime bags, 2 clear turquoise bags, 3 muted cyan bags.\n', 'mirrored black bags contain 1 plaid red bag, 3 light gold bags, 3 wavy violet bags.\n', 'vibrant fuchsia bags contain 2 dark lime bags, 2 mirrored black bags, 2 light magenta bags, 2 drab chartreuse bags.\n', 'vibrant plum bags contain 4 dim cyan bags, 3 pale maroon bags.\n', 'dark tan bags contain 3 faded white bags, 3 wavy tan bags, 4 pale indigo bags.\n', 'faded green bags contain 2 dim cyan bags, 5 dim magenta bags, 2 wavy maroon bags, 2 faded white bags.\n', 'clear black bags contain 4 striped green bags, 2 dim violet bags, 1 dull tan bag.\n', 'light olive bags contain 5 striped indigo bags, 3 dim coral bags, 1 drab bronze bag, 3 mirrored beige bags.\n', 'dim black bags contain 1 faded tan bag, 5 shi
# ...

# %%
i=0
while i< len(Lines):
    line = str(Lines[i])
    line = line.replace(' bags contain ', ', ')
    line = line.split(', ')
    Lines[i]=line
    i+=1
Lines
# Out:
# [['clear maroon', '1 dull lavender bag.\n'],
#  ['wavy turquoise',
#   '4 vibrant magenta bags',
#   '4 light violet bags',
#   '5 bright gold bags',
#   '2 faded black bags.\n'],
#  ['wavy beige',
#   '3 plaid magenta bags',
#   '3 wavy lime bags',
#   '2 clear turquoise bags',
#   '3 muted cyan bags.\n'],
#  ['mirrored black',
#   '1 plaid red bag',
#   '3 light gold bags',
#   '3 wavy violet bags.\n'],
#  ['vibrant fuchsia',
#   '2 dark lime bags',
#   '2 mirrored black bags',
#   '2 light magenta bags',
#   '2 drab chartreuse bags.\n'],
#  ['vibrant plum', '4 dim cyan bags', '3 pale maroon bags.\n'],
#  ['dark tan',
#   '3 faded white bags',
#   '3 wavy tan bags',
#   '4 pale indigo bags.\n'],
#  ['faded green',
#   '2 dim cyan bags',
#   '5 dim magenta bags',
#   '2 wavy maroon bags',
#   '2 faded white bags.\n'],
#  ['clear black',
#   '4 striped green bags',
#   '2 dim violet bags',
#   '1 dull tan bag.\n'],
#  ['light olive',
#   '5 striped indigo bags',
# ...

# %%
i = 0
j=0
while i<len(Lines):
    print(len(Lines[i]))
    while j < len(Lines[i]):
        #if bag contains bags we are looking for, bag will be added in list
        #bags we are looking for grows with each new bag containing bags we are looking for 
    j=0
    i+=1
# Out:
#   File "<ipython-input-67-2772f2a410b6>", line 7
#     j=0
#     ^
# IndentationError: expected an indented block

# %%
Liste2={'a':'b', 'b':'c', 'c':'b'}
ListeGesuchteTaschen=['a']
for charw in ListeGesuchteTaschen:
    if Liste2[charw] in ListeGesuchteTaschen:
        ListeGesuchteTaschen.append(charw)
print(ListeGesuchteTaschen)
# Out:
# ['a']

# %%
Liste2['a']
# Out:
# 'b'

# %%
#Aufgabe7.csv muss durchlaufen werden auf der Suche nach 'shiny gold'
#Alle Taschen, die diese Tasche beinhalten, kommen in eine Liste
#Aufgabe7.csv muss mit dieser Liste durchlaufen werden und alle neuen Taschen werden hinzugefügt.
#Sobald keine neue Tasche mehr dazu kommt, ist len(Liste) die Lösung
#Function, die Aufgabe7.csv durchsucht
#Aufruf Function mit Liste
